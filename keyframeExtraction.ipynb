# %% [markdown]
# # Keyframe Extraction with Byte Offsets
#
# This notebook extracts keyframes from a video and stores their byte offsets for efficient sequential decoding.

# %%
import subprocess
import json
import os
from pathlib import Path

# %%
# Video path - update this to your video file
video_path = "/Users/kuntalsuman/Downloads/demo.mov"

# Verify the file exists
if not os.path.exists(video_path):
    raise FileNotFoundError(f"Video file not found: {video_path}")

print(f"Video file: {video_path}")
print(f"File size: {os.path.getsize(video_path):,} bytes")
# Out:
# Video file: /Users/kuntalsuman/Downloads/demo.mov
# File size: 18,712,861 bytes

# %% [markdown]
# ## Extract Keyframe Information with Byte Offsets
#
# We'll use FFprobe to extract detailed packet information including:
# - Frame type (I-frames are keyframes)
# - Byte position (offset in the file)
# - Presentation timestamp (PTS)
# - Frame number

# %%
def extract_keyframe_offsets(video_path):
    """
    Extract keyframe information including byte offsets from a video file.
    
    Returns:
        list: List of dictionaries containing keyframe metadata
    """
    # Use ffprobe to get packet information
    cmd = [
        'ffprobe',
        '-v', 'error',
        '-select_streams', 'v:0',  # Select first video stream
        '-show_entries', 'packet=pts_time,pos,flags,size',  # Get timestamp, position, flags, and size
        '-of', 'json',  # Output as JSON
        video_path
    ]
    
    try:
        result = subprocess.run(cmd, capture_output=True, text=True, check=True)
        data = json.loads(result.stdout)
        
        keyframes = []
        frame_num = 0
        
        for packet in data.get('packets', []):
            # Check if this is a keyframe (I-frame)
            # The 'K' flag indicates a keyframe
            if 'K' in packet.get('flags', ''):
                keyframe_info = {
                    'frame_number': frame_num,
                    'byte_offset': int(packet.get('pos', -1)),
                    'pts_time': float(packet.get('pts_time', 0)),
                    'packet_size': int(packet.get('size', 0))
                }
                keyframes.append(keyframe_info)
            frame_num += 1
        
        return keyframes
    
    except subprocess.CalledProcessError as e:
        print(f"Error running ffprobe: {e}")
        print(f"stderr: {e.stderr}")
        raise
    except json.JSONDecodeError as e:
        print(f"Error parsing JSON output: {e}")
        raise

# %%
# Extract keyframe offsets
print("Extracting keyframe information...")
keyframes = extract_keyframe_offsets(video_path)

print(f"\nFound {len(keyframes)} keyframes")
print("\nFirst 5 keyframes:")
for i, kf in enumerate(keyframes[:5]):
    print(f"\nKeyframe {i+1}:")
    print(f"  Frame Number: {kf['frame_number']}")
    print(f"  Byte Offset: {kf['byte_offset']:,}")
    print(f"  Timestamp: {kf['pts_time']:.3f}s")
    print(f"  Packet Size: {kf['packet_size']:,} bytes")
# Out:
# Extracting keyframe information...
#
# Found 24 keyframes
#
# First 5 keyframes:
#
# Keyframe 1:
#   Frame Number: 0
#   Byte Offset: 36
#   Timestamp: 0.000s
#   Packet Size: 115,518 bytes
#
# Keyframe 2:
#   Frame Number: 33
#   Byte Offset: 715,662
#   Timestamp: 1.376s
#   Packet Size: 79,365 bytes
#
# Keyframe 3:
#   Frame Number: 77
#   Byte Offset: 1,513,552
#   Timestamp: 3.212s
#   Packet Size: 73,328 bytes
#
# Keyframe 4:
#   Frame Number: 164
#   Byte Offset: 2,956,882
#   Timestamp: 6.840s
#   Packet Size: 38,628 bytes
#
# Keyframe 5:
#   Frame Number: 221
#   Byte Offset: 3,460,108
#   Timestamp: 9.218s
#   Packet Size: 117,067 bytes

# %% [markdown]
# ## Save Keyframe Metadata
#
# Save the keyframe information to a JSON file for later use.

# %%
def seconds_to_mmss_ms(seconds):
    """
    Convert seconds (float) to MM:SS:mmm format.
    
    Args:
        seconds (float): Time in seconds (e.g., 54.179125)
    
    Returns:
        str: Time in MM:SS:mmm format (e.g., "00:54:179")
    
    Examples:
        >>> seconds_to_mmss_ms(54.179125)
        '00:54:179'
        >>> seconds_to_mmss_ms(125.5)
        '02:05:500'
        >>> seconds_to_mmss_ms(3661.123)
        '61:01:123'
    """
    # Extract minutes
    minutes = int(seconds // 60)
    
    # Extract remaining seconds
    remaining_seconds = seconds % 60
    
    # Extract whole seconds and milliseconds
    secs = int(remaining_seconds)
    milliseconds = int((remaining_seconds - secs) * 1000)
    
    # Format as MM:SS:mmm
    return f"{minutes:02d}:{secs:02d}:{milliseconds:03d}"

# %%
keyframes[21]
# Out:
# {'frame_number': 1209,
#  'byte_offset': 16423152,
#  'pts_time': 50.425375,
#  'packet_size': 120290}

# %% [markdown]
# # Decode and display frames

# %%
import ffmpeg

# %%
def seconds_to_mmss_ms(seconds):
    """
    Convert seconds (float) to MM:SS:mmm format.
    
    Args:
        seconds (float): Time in seconds (e.g., 54.179125)
    
    Returns:
        str: Time in MM:SS:mmm format (e.g., "00:54:179")
    
    Examples:
        >>> seconds_to_mmss_ms(54.179125)
        '00:54:179'
        >>> seconds_to_mmss_ms(125.5)
        '02:05:500'
        >>> seconds_to_mmss_ms(3661.123)
        '61:01:123'
    """
    # Extract minutes
    minutes = int(seconds // 60)
    
    # Extract remaining seconds
    remaining_seconds = seconds % 60
    
    # Extract whole seconds and milliseconds
    secs = int(remaining_seconds)
    milliseconds = int((remaining_seconds - secs) * 1000)
    
    # Format as MM:SS:mmm
    return f"{minutes:02d}:{secs:02d}:{milliseconds:03d}"

# %%
time = keyframes[0].get("pts_time")
folder_name = "keyframes"
time
# Out:
# 0.0

# %%
def get_keyframe_image(time, number):
    ffmpeg_command = f"ffmpeg -ss {time} -i {video_path} -frames:v 1 -c:v png -f image2 - > {folder_name}/frame{number}.png"
    subprocess.call(ffmpeg_command, shell=True)

# %%
get_keyframe_image(0.0, 1)
# Out:
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kuntalsuman/Downloads/demo.mov':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Duration: 00:01:00.06, start: 0.000000, bitrate: 2492 kb/s
#   Stream #0:0[0x1]: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x150e08000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x150e08000] [swscaler @ 0x121268000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x150e08000] [swscaler @ 0x121278000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x150e08000] [swscaler @ 0x121288000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x150e08000] [swscaler @ 0x121298000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x150e08000] [swscaler @ 0x1212a8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x150e08000] [swscaler @ 0x1212b8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x150e08000] [swscaler @ 0x1212c8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x150e08000] [swscaler @ 0x1212d8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x150e08000] [swscaler @ 0x1212e8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x150e08000] [swscaler @ 0x1212f8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x150e08000] [swscaler @ 0x121308000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x150e08000] [swscaler @ 0x121318000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x150e08000] [swscaler @ 0x121328000] No accelerated colorspace conversion found from yuv420p to rgb24.
# Output #0, image2, to 'pipe:':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Stream #0:0: Video: png, rgb24(pc, gbr/bt709/bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 23.98 fps, 23.98 tbn (default)
#     Metadata:
#       encoder         : Lavc62.11.100 png
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
# [image2 @ 0x14a805110] The specified filename 'pipe:' does not contain an image sequence pattern or a pattern is invalid.
# [image2 @ 0x14a805110] Use a pattern such as %03d for an image sequence or use the -update option (with -frames:v 1 if needed) to write a single image.
# [out#0/image2 @ 0x14a805050] video:2382KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame=    1 fps=0.0 q=-0.0 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=0.163x elapsed=0:00:00.25

# %% [markdown]
# # make a folder to store the keyframes

# %%
import os

# %%
folder_name = "keyframes"
os.makedirs(folder_name, exist_ok=True)

# %% [markdown]
# delete all the files in the folder

# %%
for file in Path(folder_name).iterdir():
    if file.is_file():
        file.unlink()

# %%
no = 0
for keyframe in keyframes:
    no += 1
    time = keyframe.get("pts_time")
    get_keyframe_image(time, no)
# Out:
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kuntalsuman/Downloads/demo.mov':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Duration: 00:01:00.06, start: 0.000000, bitrate: 2492 kb/s
#   Stream #0:0[0x1]: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x3000a0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x3000a0000] [swscaler @ 0x139de8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x3000a0000] [swscaler @ 0x139df8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x3000a0000] [swscaler @ 0x139e08000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x3000a0000] [swscaler @ 0x139e18000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x3000a0000] [swscaler @ 0x139e28000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x3000a0000] [swscaler @ 0x139e38000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x3000a0000] [swscaler @ 0x139e48000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x3000a0000] [swscaler @ 0x139e58000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x3000a0000] [swscaler @ 0x139e68000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x3000a0000] [swscaler @ 0x139e78000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x3000a0000] [swscaler @ 0x139e88000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x3000a0000] [swscaler @ 0x139e98000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x3000a0000] [swscaler @ 0x139ea8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# Output #0, image2, to 'pipe:':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Stream #0:0: Video: png, rgb24(pc, gbr/bt709/bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 23.98 fps, 23.98 tbn (default)
#     Metadata:
#       encoder         : Lavc62.11.100 png
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
# [image2 @ 0x143f1f740] The specified filename 'pipe:' does not contain an image sequence pattern or a pattern is invalid.
# [image2 @ 0x143f1f740] Use a pattern such as %03d for an image sequence or use the -update option (with -frames:v 1 if needed) to write a single image.
# [out#0/image2 @ 0x143f1f680] video:2382KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame=    1 fps=0.0 q=-0.0 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=0.16x elapsed=0:00:00.26
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kuntalsuman/Downloads/demo.mov':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Duration: 00:01:00.06, start: 0.000000, bitrate: 2492 kb/s
#   Stream #0:0[0x1]: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [h264 @ 0x13df18d60] mmco: unref short failure
# [swscaler @ 0x1604d8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1604d8000] [swscaler @ 0x1604e8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1604d8000] [swscaler @ 0x1604f8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1604d8000] [swscaler @ 0x160508000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1604d8000] [swscaler @ 0x160518000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1604d8000] [swscaler @ 0x160528000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1604d8000] [swscaler @ 0x160538000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1604d8000] [swscaler @ 0x160548000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1604d8000] [swscaler @ 0x160558000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1604d8000] [swscaler @ 0x160568000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1604d8000] [swscaler @ 0x160578000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1604d8000] [swscaler @ 0x160588000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1604d8000] [swscaler @ 0x160598000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1604d8000] [swscaler @ 0x1605a8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# Output #0, image2, to 'pipe:':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Stream #0:0: Video: png, rgb24(pc, gbr/bt709/bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 23.98 fps, 23.98 tbn (default)
#     Metadata:
#       encoder         : Lavc62.11.100 png
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
# [image2 @ 0x13df05110] The specified filename 'pipe:' does not contain an image sequence pattern or a pattern is invalid.
# [image2 @ 0x13df05110] Use a pattern such as %03d for an image sequence or use the -update option (with -frames:v 1 if needed) to write a single image.
# [out#0/image2 @ 0x13df05050] video:1994KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame=    1 fps=0.0 q=-0.0 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=0.164x elapsed=0:00:00.25
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kuntalsuman/Downloads/demo.mov':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Duration: 00:01:00.06, start: 0.000000, bitrate: 2492 kb/s
#   Stream #0:0[0x1]: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x1602e8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1602e8000] [swscaler @ 0x1484e0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1602e8000] [swscaler @ 0x1484f0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1602e8000] [swscaler @ 0x148500000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1602e8000] [swscaler @ 0x148510000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1602e8000] [swscaler @ 0x148520000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1602e8000] [swscaler @ 0x109490000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1602e8000] [swscaler @ 0x1094a0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1602e8000] [swscaler @ 0x118ae8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1602e8000] [swscaler @ 0x118af8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1602e8000] [swscaler @ 0x118b08000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1602e8000] [swscaler @ 0x118b18000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1602e8000] [swscaler @ 0x118b28000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1602e8000] [swscaler @ 0x118b38000] No accelerated colorspace conversion found from yuv420p to rgb24.
# Output #0, image2, to 'pipe:':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Stream #0:0: Video: png, rgb24(pc, gbr/bt709/bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 23.98 fps, 23.98 tbn (default)
#     Metadata:
#       encoder         : Lavc62.11.100 png
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
# [image2 @ 0x131f05110] The specified filename 'pipe:' does not contain an image sequence pattern or a pattern is invalid.
# [image2 @ 0x131f05110] Use a pattern such as %03d for an image sequence or use the -update option (with -frames:v 1 if needed) to write a single image.
# [out#0/image2 @ 0x131f05050] video:1577KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame=    1 fps=0.0 q=-0.0 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=0.218x elapsed=0:00:00.19
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kuntalsuman/Downloads/demo.mov':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Duration: 00:01:00.06, start: 0.000000, bitrate: 2492 kb/s
#   Stream #0:0[0x1]: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x178a80000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x178a80000] [swscaler @ 0x178a90000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x178a80000] [swscaler @ 0x178aa0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x178a80000] [swscaler @ 0x178ab0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x178a80000] [swscaler @ 0x178ac0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x178a80000] [swscaler @ 0x178ad0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x178a80000] [swscaler @ 0x178ae0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x178a80000] [swscaler @ 0x178af0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x178a80000] [swscaler @ 0x178b00000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x178a80000] [swscaler @ 0x178b10000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x178a80000] [swscaler @ 0x178b20000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x178a80000] [swscaler @ 0x178b30000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x178a80000] [swscaler @ 0x178b40000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x178a80000] [swscaler @ 0x178b50000] No accelerated colorspace conversion found from yuv420p to rgb24.
# Output #0, image2, to 'pipe:':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Stream #0:0: Video: png, rgb24(pc, gbr/bt709/bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 23.98 fps, 23.98 tbn (default)
#     Metadata:
#       encoder         : Lavc62.11.100 png
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
# [image2 @ 0x127f04230] The specified filename 'pipe:' does not contain an image sequence pattern or a pattern is invalid.
# [image2 @ 0x127f04230] Use a pattern such as %03d for an image sequence or use the -update option (with -frames:v 1 if needed) to write a single image.
# [out#0/image2 @ 0x127f04160] video:852KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame=    1 fps=0.0 q=-0.0 Lsize=N/A time=00:00:00.04 bitrate=N/A speed= 0.5x elapsed=0:00:00.08
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kuntalsuman/Downloads/demo.mov':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Duration: 00:01:00.06, start: 0.000000, bitrate: 2492 kb/s
#   Stream #0:0[0x1]: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x1581f8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1581f8000] [swscaler @ 0x150508000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1581f8000] [swscaler @ 0x150518000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1581f8000] [swscaler @ 0x150528000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1581f8000] [swscaler @ 0x150538000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1581f8000] [swscaler @ 0x150548000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1581f8000] [swscaler @ 0x150558000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1581f8000] [swscaler @ 0x150568000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1581f8000] [swscaler @ 0x150578000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1581f8000] [swscaler @ 0x150588000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1581f8000] [swscaler @ 0x150598000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1581f8000] [swscaler @ 0x1505a8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1581f8000] [swscaler @ 0x1505b8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1581f8000] [swscaler @ 0x1505c8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# Output #0, image2, to 'pipe:':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Stream #0:0: Video: png, rgb24(pc, gbr/bt709/bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 23.98 fps, 23.98 tbn (default)
#     Metadata:
#       encoder         : Lavc62.11.100 png
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
# [image2 @ 0x13d731e40] The specified filename 'pipe:' does not contain an image sequence pattern or a pattern is invalid.
# [image2 @ 0x13d731e40] Use a pattern such as %03d for an image sequence or use the -update option (with -frames:v 1 if needed) to write a single image.
# [out#0/image2 @ 0x13d731d80] video:1885KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame=    1 fps=0.0 q=-0.0 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=0.191x elapsed=0:00:00.21
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kuntalsuman/Downloads/demo.mov':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Duration: 00:01:00.06, start: 0.000000, bitrate: 2492 kb/s
#   Stream #0:0[0x1]: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x178080000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x178080000] [swscaler @ 0x308108000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x178080000] [swscaler @ 0x308118000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x178080000] [swscaler @ 0x308128000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x178080000] [swscaler @ 0x308138000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x178080000] [swscaler @ 0x308148000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x178080000] [swscaler @ 0x308158000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x178080000] [swscaler @ 0x308168000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x178080000] [swscaler @ 0x308178000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x178080000] [swscaler @ 0x308188000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x178080000] [swscaler @ 0x308198000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x178080000] [swscaler @ 0x3081a8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x178080000] [swscaler @ 0x3081b8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x178080000] [swscaler @ 0x3081c8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# Output #0, image2, to 'pipe:':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Stream #0:0: Video: png, rgb24(pc, gbr/bt709/bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 23.98 fps, 23.98 tbn (default)
#     Metadata:
#       encoder         : Lavc62.11.100 png
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
# [image2 @ 0x137e05110] The specified filename 'pipe:' does not contain an image sequence pattern or a pattern is invalid.
# [image2 @ 0x137e05110] Use a pattern such as %03d for an image sequence or use the -update option (with -frames:v 1 if needed) to write a single image.
# [out#0/image2 @ 0x137e05050] video:2544KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame=    1 fps=0.0 q=-0.0 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=0.167x elapsed=0:00:00.24
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kuntalsuman/Downloads/demo.mov':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Duration: 00:01:00.06, start: 0.000000, bitrate: 2492 kb/s
#   Stream #0:0[0x1]: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x1504d0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1504d0000] [swscaler @ 0x1504e0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1504d0000] [swscaler @ 0x1504f0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1504d0000] [swscaler @ 0x150500000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1504d0000] [swscaler @ 0x150510000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1504d0000] [swscaler @ 0x150520000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1504d0000] [swscaler @ 0x150530000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1504d0000] [swscaler @ 0x150540000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1504d0000] [swscaler @ 0x150550000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1504d0000] [swscaler @ 0x1586e8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1504d0000] [swscaler @ 0x1586f8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1504d0000] [swscaler @ 0x158708000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1504d0000] [swscaler @ 0x158718000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1504d0000] [swscaler @ 0x158728000] No accelerated colorspace conversion found from yuv420p to rgb24.
# Output #0, image2, to 'pipe:':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Stream #0:0: Video: png, rgb24(pc, gbr/bt709/bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 23.98 fps, 23.98 tbn (default)
#     Metadata:
#       encoder         : Lavc62.11.100 png
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
# [image2 @ 0x126f05110] The specified filename 'pipe:' does not contain an image sequence pattern or a pattern is invalid.
# [image2 @ 0x126f05110] Use a pattern such as %03d for an image sequence or use the -update option (with -frames:v 1 if needed) to write a single image.
# [out#0/image2 @ 0x126f05050] video:1354KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame=    1 fps=0.0 q=-0.0 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=0.233x elapsed=0:00:00.17
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kuntalsuman/Downloads/demo.mov':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Duration: 00:01:00.06, start: 0.000000, bitrate: 2492 kb/s
#   Stream #0:0[0x1]: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x300118000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x300118000] [swscaler @ 0x130c68000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x300118000] [swscaler @ 0x130f18000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x300118000] [swscaler @ 0x130f28000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x300118000] [swscaler @ 0x130f38000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x300118000] [swscaler @ 0x130f48000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x300118000] [swscaler @ 0x130f58000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x300118000] [swscaler @ 0x131f00000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x300118000] [swscaler @ 0x131f10000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x300118000] [swscaler @ 0x131f20000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x300118000] [swscaler @ 0x151260000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x300118000] [swscaler @ 0x151270000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x300118000] [swscaler @ 0x151280000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x300118000] [swscaler @ 0x151290000] No accelerated colorspace conversion found from yuv420p to rgb24.
# Output #0, image2, to 'pipe:':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Stream #0:0: Video: png, rgb24(pc, gbr/bt709/bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 23.98 fps, 23.98 tbn (default)
#     Metadata:
#       encoder         : Lavc62.11.100 png
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
# [image2 @ 0x13f704440] The specified filename 'pipe:' does not contain an image sequence pattern or a pattern is invalid.
# [image2 @ 0x13f704440] Use a pattern such as %03d for an image sequence or use the -update option (with -frames:v 1 if needed) to write a single image.
# [out#0/image2 @ 0x13f704100] video:2143KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame=    1 fps=0.0 q=-0.0 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=0.18x elapsed=0:00:00.23
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kuntalsuman/Downloads/demo.mov':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Duration: 00:01:00.06, start: 0.000000, bitrate: 2492 kb/s
#   Stream #0:0[0x1]: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x148a88000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x148a88000] [swscaler @ 0x148a98000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x148a88000] [swscaler @ 0x148aa8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x148a88000] [swscaler @ 0x148ab8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x148a88000] [swscaler @ 0x148ac8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x148a88000] [swscaler @ 0x148ad8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x148a88000] [swscaler @ 0x148ae8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x148a88000] [swscaler @ 0x148af8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x148a88000] [swscaler @ 0x148b08000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x148a88000] [swscaler @ 0x148b18000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x148a88000] [swscaler @ 0x148b28000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x148a88000] [swscaler @ 0x148b38000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x148a88000] [swscaler @ 0x148b48000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x148a88000] [swscaler @ 0x148b58000] No accelerated colorspace conversion found from yuv420p to rgb24.
# Output #0, image2, to 'pipe:':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Stream #0:0: Video: png, rgb24(pc, gbr/bt709/bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 23.98 fps, 23.98 tbn (default)
#     Metadata:
#       encoder         : Lavc62.11.100 png
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
# [image2 @ 0x117e04b70] The specified filename 'pipe:' does not contain an image sequence pattern or a pattern is invalid.
# [image2 @ 0x117e04b70] Use a pattern such as %03d for an image sequence or use the -update option (with -frames:v 1 if needed) to write a single image.
# [out#0/image2 @ 0x117e04640] video:1042KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame=    1 fps=0.0 q=-0.0 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=0.532x elapsed=0:00:00.07
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kuntalsuman/Downloads/demo.mov':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Duration: 00:01:00.06, start: 0.000000, bitrate: 2492 kb/s
#   Stream #0:0[0x1]: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x148768000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x148768000] [swscaler @ 0x148778000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x148768000] [swscaler @ 0x148788000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x148768000] [swscaler @ 0x148798000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x148768000] [swscaler @ 0x1487a8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x148768000] [swscaler @ 0x1487b8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x148768000] [swscaler @ 0x1487c8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x148768000] [swscaler @ 0x1487d8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x148768000] [swscaler @ 0x1487e8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x148768000] [swscaler @ 0x1487f8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x148768000] [swscaler @ 0x148808000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x148768000] [swscaler @ 0x148818000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x148768000] [swscaler @ 0x148828000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x148768000] [swscaler @ 0x148838000] No accelerated colorspace conversion found from yuv420p to rgb24.
# Output #0, image2, to 'pipe:':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Stream #0:0: Video: png, rgb24(pc, gbr/bt709/bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 23.98 fps, 23.98 tbn (default)
#     Metadata:
#       encoder         : Lavc62.11.100 png
#       handler_name    : ISO Media file produced by Google Inc.
# ...
# [swscaler @ 0x300008000] [swscaler @ 0x120b38000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x300008000] [swscaler @ 0x120b48000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x300008000] [swscaler @ 0x120b58000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x300008000] [swscaler @ 0x120b68000] No accelerated colorspace conversion found from yuv420p to rgb24.
# Output #0, image2, to 'pipe:':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Stream #0:0: Video: png, rgb24(pc, gbr/bt709/bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 23.98 fps, 23.98 tbn (default)
#     Metadata:
#       encoder         : Lavc62.11.100 png
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
# [image2 @ 0x15a632f50] The specified filename 'pipe:' does not contain an image sequence pattern or a pattern is invalid.
# [image2 @ 0x15a632f50] Use a pattern such as %03d for an image sequence or use the -update option (with -frames:v 1 if needed) to write a single image.
# [out#0/image2 @ 0x15a632c00] video:768KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame=    1 fps=0.0 q=-0.0 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=0.579x elapsed=0:00:00.07
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kuntalsuman/Downloads/demo.mov':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Duration: 00:01:00.06, start: 0.000000, bitrate: 2492 kb/s
#   Stream #0:0[0x1]: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x150bb0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x150bb0000] [swscaler @ 0x150bc0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x150bb0000] [swscaler @ 0x150bd0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x150bb0000] [swscaler @ 0x150be0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x150bb0000] [swscaler @ 0x150bf0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x150bb0000] [swscaler @ 0x150c00000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x150bb0000] [swscaler @ 0x150c10000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x150bb0000] [swscaler @ 0x150c20000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x150bb0000] [swscaler @ 0x150c30000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x150bb0000] [swscaler @ 0x150c40000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x150bb0000] [swscaler @ 0x150c50000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x150bb0000] [swscaler @ 0x150c60000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x150bb0000] [swscaler @ 0x150c70000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x150bb0000] [swscaler @ 0x150c80000] No accelerated colorspace conversion found from yuv420p to rgb24.
# Output #0, image2, to 'pipe:':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Stream #0:0: Video: png, rgb24(pc, gbr/bt709/bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 23.98 fps, 23.98 tbn (default)
#     Metadata:
#       encoder         : Lavc62.11.100 png
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
# [image2 @ 0x143005110] The specified filename 'pipe:' does not contain an image sequence pattern or a pattern is invalid.
# [image2 @ 0x143005110] Use a pattern such as %03d for an image sequence or use the -update option (with -frames:v 1 if needed) to write a single image.
# [out#0/image2 @ 0x143005050] video:1031KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame=    1 fps=0.0 q=-0.0 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=0.549x elapsed=0:00:00.07
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kuntalsuman/Downloads/demo.mov':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Duration: 00:01:00.06, start: 0.000000, bitrate: 2492 kb/s
#   Stream #0:0[0x1]: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x170008000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x170008000] [swscaler @ 0x170018000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x170008000] [swscaler @ 0x170028000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x170008000] [swscaler @ 0x170038000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x170008000] [swscaler @ 0x170048000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x170008000] [swscaler @ 0x170058000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x170008000] [swscaler @ 0x170068000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x170008000] [swscaler @ 0x170078000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x170008000] [swscaler @ 0x170088000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x170008000] [swscaler @ 0x170098000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x170008000] [swscaler @ 0x1700a8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x170008000] [swscaler @ 0x1700b8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x170008000] [swscaler @ 0x1700c8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x170008000] [swscaler @ 0x1700d8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# Output #0, image2, to 'pipe:':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Stream #0:0: Video: png, rgb24(pc, gbr/bt709/bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 23.98 fps, 23.98 tbn (default)
#     Metadata:
#       encoder         : Lavc62.11.100 png
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
# [image2 @ 0x1096041e0] The specified filename 'pipe:' does not contain an image sequence pattern or a pattern is invalid.
# [image2 @ 0x1096041e0] Use a pattern such as %03d for an image sequence or use the -update option (with -frames:v 1 if needed) to write a single image.
# [out#0/image2 @ 0x109604110] video:616KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame=    1 fps=0.0 q=-0.0 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=0.532x elapsed=0:00:00.07
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kuntalsuman/Downloads/demo.mov':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Duration: 00:01:00.06, start: 0.000000, bitrate: 2492 kb/s
#   Stream #0:0[0x1]: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x1388c0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1388c0000] [swscaler @ 0x1388d0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1388c0000] [swscaler @ 0x1388e0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1388c0000] [swscaler @ 0x1388f0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1388c0000] [swscaler @ 0x138900000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1388c0000] [swscaler @ 0x138910000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1388c0000] [swscaler @ 0x138920000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1388c0000] [swscaler @ 0x138930000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1388c0000] [swscaler @ 0x138940000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1388c0000] [swscaler @ 0x138950000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1388c0000] [swscaler @ 0x138960000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1388c0000] [swscaler @ 0x138970000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1388c0000] [swscaler @ 0x138980000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1388c0000] [swscaler @ 0x138990000] No accelerated colorspace conversion found from yuv420p to rgb24.
# Output #0, image2, to 'pipe:':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Stream #0:0: Video: png, rgb24(pc, gbr/bt709/bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 23.98 fps, 23.98 tbn (default)
#     Metadata:
#       encoder         : Lavc62.11.100 png
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
# [image2 @ 0x10ee04230] The specified filename 'pipe:' does not contain an image sequence pattern or a pattern is invalid.
# [image2 @ 0x10ee04230] Use a pattern such as %03d for an image sequence or use the -update option (with -frames:v 1 if needed) to write a single image.
# [out#0/image2 @ 0x10ee04160] video:571KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame=    1 fps=0.0 q=-0.0 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=0.615x elapsed=0:00:00.06

# %%
video_folder = "video_between_keyframes"

# %%
os.makedirs(video_folder, exist_ok=True)

# %%
for file in Path(video_folder).iterdir():
    if file.is_file():
        file.unlink()

# %%
def slice_videos(t0, t1, part):
    ffmpeg_command_to_slice_video = f"ffmpeg -ss 00:{t0} -to 00:{t1} -i {video_path} -c copy -avoid_negative_ts make_zero {video_folder}/slice{part}.mp4"
    subprocess.call(ffmpeg_command_to_slice_video, shell=True)

# %%
for i in range(0, 23):
    t0 = keyframes[i].get("pts_time")
    t1 = keyframes[i+1].get("pts_time")
    part = i+1
    slice_videos(t0, t1, part)
# Out:
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kuntalsuman/Downloads/demo.mov':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Duration: 00:01:00.06, start: 0.000000, bitrate: 2492 kb/s
#   Stream #0:0[0x1]: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Output #0, mp4, to 'video_between_keyframes/slice1.mp4':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Stream #0:0: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Press [q] to stop, [?] for help
# [out#0/mp4 @ 0x153905ca0] video:755KiB audio:23KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.322047%
# frame=   34 fps=0.0 q=-1.0 Lsize=     780KiB time=00:00:01.37 bitrate=4640.7kbits/s speed=2.05e+03x elapsed=0:00:00.00
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kuntalsuman/Downloads/demo.mov':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Duration: 00:01:00.06, start: 0.000000, bitrate: 2492 kb/s
#   Stream #0:0[0x1]: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Output #0, mp4, to 'video_between_keyframes/slice2.mp4':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Stream #0:0: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Press [q] to stop, [?] for help
# [out#0/mp4 @ 0x14d705050] video:823KiB audio:29KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.336400%
# frame=   45 fps=0.0 q=-1.0 Lsize=     855KiB time=00:00:01.83 bitrate=3816.1kbits/s speed=2.93e+03x elapsed=0:00:00.00
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kuntalsuman/Downloads/demo.mov':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Duration: 00:01:00.06, start: 0.000000, bitrate: 2492 kb/s
#   Stream #0:0[0x1]: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Output #0, mp4, to 'video_between_keyframes/slice3.mp4':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Stream #0:0: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Press [q] to stop, [?] for help
# [out#0/mp4 @ 0x128f05050] video:1390KiB audio:58KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.280965%
# frame=   88 fps=0.0 q=-1.0 Lsize=    1452KiB time=00:00:03.62 bitrate=3279.0kbits/s speed=4.4e+03x elapsed=0:00:00.00
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kuntalsuman/Downloads/demo.mov':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Duration: 00:01:00.06, start: 0.000000, bitrate: 2492 kb/s
#   Stream #0:0[0x1]: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Output #0, mp4, to 'video_between_keyframes/slice4.mp4':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Stream #0:0: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Press [q] to stop, [?] for help
# [out#0/mp4 @ 0x13f605050] video:568KiB audio:38KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.528647%
# frame=   58 fps=0.0 q=-1.0 Lsize=     610KiB time=00:00:02.37 bitrate=2100.8kbits/s speed=3.75e+03x elapsed=0:00:00.00
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kuntalsuman/Downloads/demo.mov':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Duration: 00:01:00.06, start: 0.000000, bitrate: 2492 kb/s
#   Stream #0:0[0x1]: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Output #0, mp4, to 'video_between_keyframes/slice5.mp4':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Stream #0:0: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Press [q] to stop, [?] for help
# [out#0/mp4 @ 0x14af27ba0] video:2404KiB audio:25KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.108686%
# frame=   38 fps=0.0 q=-1.0 Lsize=    2431KiB time=00:00:01.54 bitrate=12906.5kbits/s speed=2.15e+03x elapsed=0:00:00.00
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kuntalsuman/Downloads/demo.mov':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Duration: 00:01:00.06, start: 0.000000, bitrate: 2492 kb/s
#   Stream #0:0[0x1]: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Output #0, mp4, to 'video_between_keyframes/slice6.mp4':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Stream #0:0: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Press [q] to stop, [?] for help
# [out#0/mp4 @ 0x10de05050] video:1097KiB audio:37KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.280806%
# frame=   56 fps=0.0 q=-1.0 Lsize=    1137KiB time=00:00:02.29 bitrate=4058.8kbits/s speed=2.48e+03x elapsed=0:00:00.00
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kuntalsuman/Downloads/demo.mov':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Duration: 00:01:00.06, start: 0.000000, bitrate: 2492 kb/s
#   Stream #0:0[0x1]: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Output #0, mp4, to 'video_between_keyframes/slice7.mp4':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Stream #0:0: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Press [q] to stop, [?] for help
# [out#0/mp4 @ 0x122f05050] video:721KiB audio:29KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.378929%
# frame=   45 fps=0.0 q=-1.0 Lsize=     752KiB time=00:00:01.80 bitrate=3411.1kbits/s speed=2.93e+03x elapsed=0:00:00.00
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kuntalsuman/Downloads/demo.mov':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Duration: 00:01:00.06, start: 0.000000, bitrate: 2492 kb/s
#   Stream #0:0[0x1]: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Output #0, mp4, to 'video_between_keyframes/slice8.mp4':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Stream #0:0: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Press [q] to stop, [?] for help
# [out#0/mp4 @ 0x1599040a0] video:1855KiB audio:35KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.164648%
# frame=   53 fps=0.0 q=-1.0 Lsize=    1893KiB time=00:00:02.16 bitrate=7151.6kbits/s speed=1.99e+03x elapsed=0:00:00.00
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kuntalsuman/Downloads/demo.mov':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Duration: 00:01:00.06, start: 0.000000, bitrate: 2492 kb/s
#   Stream #0:0[0x1]: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Output #0, mp4, to 'video_between_keyframes/slice9.mp4':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Stream #0:0: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Press [q] to stop, [?] for help
# [out#0/mp4 @ 0x12ee040d0] video:781KiB audio:51KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.451255%
# frame=   78 fps=0.0 q=-1.0 Lsize=     836KiB time=00:00:03.21 bitrate=2133.2kbits/s speed=4.48e+03x elapsed=0:00:00.00
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kuntalsuman/Downloads/demo.mov':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Duration: 00:01:00.06, start: 0.000000, bitrate: 2492 kb/s
#   Stream #0:0[0x1]: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Output #0, mp4, to 'video_between_keyframes/slice10.mp4':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Stream #0:0: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Press [q] to stop, [?] for help
# [out#0/mp4 @ 0x14e005050] video:374KiB audio:27KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.670290%
# frame=   41 fps=0.0 q=-1.0 Lsize=     404KiB time=00:00:01.66 bitrate=1984.1kbits/s speed=3.1e+03x elapsed=0:00:00.00
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kuntalsuman/Downloads/demo.mov':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Duration: 00:01:00.06, start: 0.000000, bitrate: 2492 kb/s
#   Stream #0:0[0x1]: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Output #0, mp4, to 'video_between_keyframes/slice11.mp4':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Stream #0:0: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Press [q] to stop, [?] for help
# [out#0/mp4 @ 0x141f05050] video:433KiB audio:28KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.594629%
# frame=   43 fps=0.0 q=-1.0 Lsize=     464KiB time=00:00:01.75 bitrate=2168.6kbits/s speed=3.04e+03x elapsed=0:00:00.00
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kuntalsuman/Downloads/demo.mov':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Duration: 00:01:00.06, start: 0.000000, bitrate: 2492 kb/s
#   Stream #0:0[0x1]: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Output #0, mp4, to 'video_between_keyframes/slice12.mp4':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Stream #0:0: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Press [q] to stop, [?] for help
# [out#0/mp4 @ 0x12c105050] video:681KiB audio:43KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.469397%
# frame=   65 fps=0.0 q=-1.0 Lsize=     727KiB time=00:00:02.66 bitrate=2231.7kbits/s speed=4.39e+03x elapsed=0:00:00.00
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kuntalsuman/Downloads/demo.mov':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Duration: 00:01:00.06, start: 0.000000, bitrate: 2492 kb/s
#   Stream #0:0[0x1]: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Output #0, mp4, to 'video_between_keyframes/slice13.mp4':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Stream #0:0: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Press [q] to stop, [?] for help
# [out#0/mp4 @ 0x127005050] video:489KiB audio:28KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.525115%
# frame=   42 fps=0.0 q=-1.0 Lsize=     520KiB time=00:00:01.71 bitrate=2492.4kbits/s speed=3.06e+03x elapsed=0:00:00.00
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kuntalsuman/Downloads/demo.mov':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Duration: 00:01:00.06, start: 0.000000, bitrate: 2492 kb/s
#   Stream #0:0[0x1]: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Output #0, mp4, to 'video_between_keyframes/slice14.mp4':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Stream #0:0: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Press [q] to stop, [?] for help
# [out#0/mp4 @ 0x142f27480] video:961KiB audio:79KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.490417%
# frame=  121 fps=0.0 q=-1.0 Lsize=    1045KiB time=00:00:05.00 bitrate=1710.7kbits/s speed=5.3e+03x elapsed=0:00:00.00
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kuntalsuman/Downloads/demo.mov':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Duration: 00:01:00.06, start: 0.000000, bitrate: 2492 kb/s
#   Stream #0:0[0x1]: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Output #0, mp4, to 'video_between_keyframes/slice15.mp4':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Stream #0:0: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
# ...
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kuntalsuman/Downloads/demo.mov':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Duration: 00:01:00.06, start: 0.000000, bitrate: 2492 kb/s
#   Stream #0:0[0x1]: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Output #0, mp4, to 'video_between_keyframes/slice19.mp4':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Stream #0:0: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Press [q] to stop, [?] for help
# [out#0/mp4 @ 0x15c105050] video:825KiB audio:74KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.534885%
# frame=  113 fps=0.0 q=-1.0 Lsize=     904KiB time=00:00:04.67 bitrate=1584.7kbits/s speed=4.15e+03x elapsed=0:00:00.00
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kuntalsuman/Downloads/demo.mov':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Duration: 00:01:00.06, start: 0.000000, bitrate: 2492 kb/s
#   Stream #0:0[0x1]: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Output #0, mp4, to 'video_between_keyframes/slice20.mp4':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Stream #0:0: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Press [q] to stop, [?] for help
# [out#0/mp4 @ 0x159e32c40] video:399KiB audio:20KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.565075%
# frame=   30 fps=0.0 q=-1.0 Lsize=     421KiB time=00:00:01.20 bitrate=2852.1kbits/s speed=2.54e+03x elapsed=0:00:00.00
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kuntalsuman/Downloads/demo.mov':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Duration: 00:01:00.06, start: 0.000000, bitrate: 2492 kb/s
#   Stream #0:0[0x1]: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Output #0, mp4, to 'video_between_keyframes/slice21.mp4':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Stream #0:0: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Press [q] to stop, [?] for help
# [out#0/mp4 @ 0x113e04090] video:320KiB audio:21KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.713735%
# frame=   32 fps=0.0 q=-1.0 Lsize=     343KiB time=00:00:01.29 bitrate=2174.9kbits/s speed= 416x elapsed=0:00:00.00
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kuntalsuman/Downloads/demo.mov':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Duration: 00:01:00.06, start: 0.000000, bitrate: 2492 kb/s
#   Stream #0:0[0x1]: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Output #0, mp4, to 'video_between_keyframes/slice22.mp4':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Stream #0:0: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Press [q] to stop, [?] for help
# [out#0/mp4 @ 0x125004080] video:765KiB audio:45KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.428848%
# frame=   68 fps=0.0 q=-1.0 Lsize=     813KiB time=00:00:02.79 bitrate=2383.3kbits/s speed=4.18e+03x elapsed=0:00:00.00
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kuntalsuman/Downloads/demo.mov':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Duration: 00:01:00.06, start: 0.000000, bitrate: 2492 kb/s
#   Stream #0:0[0x1]: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Output #0, mp4, to 'video_between_keyframes/slice23.mp4':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Stream #0:0: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Press [q] to stop, [?] for help
# [out#0/mp4 @ 0x152005c00] video:253KiB audio:16KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.821407%
# frame=   24 fps=0.0 q=-1.0 Lsize=     271KiB time=00:00:00.95 bitrate=2312.3kbits/s speed=2.37e+03x elapsed=0:00:00.00
