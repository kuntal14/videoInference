# %% [markdown]
# # Keyframe Extraction with Byte Offsets
#
# This notebook extracts keyframes from a video and stores their byte offsets for efficient sequential decoding.

# %%
import subprocess
import json
import os
from pathlib import Path

# %%
# Video path - update this to your video file
video_path = "/Users/kuntalsuman/Downloads/demo.mov"

# Verify the file exists
if not os.path.exists(video_path):
    raise FileNotFoundError(f"Video file not found: {video_path}")

print(f"Video file: {video_path}")
print(f"File size: {os.path.getsize(video_path):,} bytes")
# Out:
# Video file: /Users/kuntalsuman/Downloads/demo.mov
# File size: 18,712,861 bytes

# %% [markdown]
# ## Extract Keyframe Information with Byte Offsets
#
# We'll use FFprobe to extract detailed packet information including:
# - Frame type (I-frames are keyframes)
# - Byte position (offset in the file)
# - Presentation timestamp (PTS)
# - Frame number

# %%
def extract_keyframe_offsets(video_path):
    """
    Extract keyframe information including byte offsets from a video file.
    
    Returns:
        list: List of dictionaries containing keyframe metadata
    """
    # Use ffprobe to get packet information
    cmd = [
        'ffprobe',
        '-v', 'error',
        '-select_streams', 'v:0',  # Select first video stream
        '-show_entries', 'packet=pts_time,pos,flags,size',  # Get timestamp, position, flags, and size
        '-of', 'json',  # Output as JSON
        video_path
    ]
    
    try:
        result = subprocess.run(cmd, capture_output=True, text=True, check=True)
        data = json.loads(result.stdout)
        
        keyframes = []
        frame_num = 0
        
        for packet in data.get('packets', []):
            # Check if this is a keyframe (I-frame)
            # The 'K' flag indicates a keyframe
            if 'K' in packet.get('flags', ''):
                keyframe_info = {
                    'frame_number': frame_num,
                    'byte_offset': int(packet.get('pos', -1)),
                    'pts_time': float(packet.get('pts_time', 0)),
                    'packet_size': int(packet.get('size', 0))
                }
                keyframes.append(keyframe_info)
            frame_num += 1
        
        return keyframes
    
    except subprocess.CalledProcessError as e:
        print(f"Error running ffprobe: {e}")
        print(f"stderr: {e.stderr}")
        raise
    except json.JSONDecodeError as e:
        print(f"Error parsing JSON output: {e}")
        raise

# %%
# Extract keyframe offsets
print("Extracting keyframe information...")
keyframes = extract_keyframe_offsets(video_path)

print(f"\nFound {len(keyframes)} keyframes")
print("\nFirst 5 keyframes:")
for i, kf in enumerate(keyframes[:5]):
    print(f"\nKeyframe {i+1}:")
    print(f"  Frame Number: {kf['frame_number']}")
    print(f"  Byte Offset: {kf['byte_offset']:,}")
    print(f"  Timestamp: {kf['pts_time']:.3f}s")
    print(f"  Packet Size: {kf['packet_size']:,} bytes")
# Out:
# Extracting keyframe information...
#
# Found 24 keyframes
#
# First 5 keyframes:
#
# Keyframe 1:
#   Frame Number: 0
#   Byte Offset: 36
#   Timestamp: 0.000s
#   Packet Size: 115,518 bytes
#
# Keyframe 2:
#   Frame Number: 33
#   Byte Offset: 715,662
#   Timestamp: 1.376s
#   Packet Size: 79,365 bytes
#
# Keyframe 3:
#   Frame Number: 77
#   Byte Offset: 1,513,552
#   Timestamp: 3.212s
#   Packet Size: 73,328 bytes
#
# Keyframe 4:
#   Frame Number: 164
#   Byte Offset: 2,956,882
#   Timestamp: 6.840s
#   Packet Size: 38,628 bytes
#
# Keyframe 5:
#   Frame Number: 221
#   Byte Offset: 3,460,108
#   Timestamp: 9.218s
#   Packet Size: 117,067 bytes

# %% [markdown]
# ## Save Keyframe Metadata
#
# Save the keyframe information to a JSON file for later use.

# %%
def seconds_to_mmss_ms(seconds):
    """
    Convert seconds (float) to MM:SS:mmm format.
    
    Args:
        seconds (float): Time in seconds (e.g., 54.179125)
    
    Returns:
        str: Time in MM:SS:mmm format (e.g., "00:54:179")
    
    Examples:
        >>> seconds_to_mmss_ms(54.179125)
        '00:54:179'
        >>> seconds_to_mmss_ms(125.5)
        '02:05:500'
        >>> seconds_to_mmss_ms(3661.123)
        '61:01:123'
    """
    # Extract minutes
    minutes = int(seconds // 60)
    
    # Extract remaining seconds
    remaining_seconds = seconds % 60
    
    # Extract whole seconds and milliseconds
    secs = int(remaining_seconds)
    milliseconds = int((remaining_seconds - secs) * 1000)
    
    # Format as MM:SS:mmm
    return f"{minutes:02d}:{secs:02d}:{milliseconds:03d}"

# %%
# Save to JSON file
output_file = "keyframe_offsets.json"

metadata = {
    'video_path': video_path,
    'video_file_size': video_file_size,
    'total_keyframes': len(bounded_keyframes),
    'keyframes': bounded_keyframes
}

with open(output_file, 'w') as f:
    json.dump(metadata, f, indent=2)

print(f"\nKeyframe metadata saved to: {output_file}")
print(f"Total keyframes: {len(bounded_keyframes)}")
# Out:
# Keyframe metadata saved to: keyframe_offsets.json
# Total keyframes: 24

# %%
keyframes[23]
# Out:
# {'frame_number': 1299,
#  'byte_offset': 17421683,
#  'pts_time': 54.179125,
#  'packet_size': 48278}

# %% [markdown]
# # Decode and display frames

# %%
import ffmpeg

# %%
def seconds_to_mmss_ms(seconds):
    """
    Convert seconds (float) to MM:SS:mmm format.
    
    Args:
        seconds (float): Time in seconds (e.g., 54.179125)
    
    Returns:
        str: Time in MM:SS:mmm format (e.g., "00:54:179")
    
    Examples:
        >>> seconds_to_mmss_ms(54.179125)
        '00:54:179'
        >>> seconds_to_mmss_ms(125.5)
        '02:05:500'
        >>> seconds_to_mmss_ms(3661.123)
        '61:01:123'
    """
    # Extract minutes
    minutes = int(seconds // 60)
    
    # Extract remaining seconds
    remaining_seconds = seconds % 60
    
    # Extract whole seconds and milliseconds
    secs = int(remaining_seconds)
    milliseconds = int((remaining_seconds - secs) * 1000)
    
    # Format as MM:SS:mmm
    return f"{minutes:02d}:{secs:02d}:{milliseconds:03d}"

# %%
time = keyframes[0].get("pts_time")
time
# Out:
# 0.0

# %%
def get_keyframe_image(time, number):
    ffmpeg_command = f"ffmpeg -ss {time} -i {video_path} -frames:v 1 -c:v png -f image2 - > {folder_name}/frame{number}.png"
    subprocess.call(ffmpeg_command, shell=True)

# %%
get_keyframe_image(0.0, 1)
# Out:
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kuntalsuman/Downloads/demo.mov':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Duration: 00:01:00.06, start: 0.000000, bitrate: 2492 kb/s
#   Stream #0:0[0x1]: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x308008000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x308008000] [swscaler @ 0x308018000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x308008000] [swscaler @ 0x308028000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x308008000] [swscaler @ 0x308038000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x308008000] [swscaler @ 0x308048000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x308008000] [swscaler @ 0x308058000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x308008000] [swscaler @ 0x308068000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x308008000] [swscaler @ 0x300208000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x308008000] [swscaler @ 0x178338000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x308008000] [swscaler @ 0x300218000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x308008000] [swscaler @ 0x14a200000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x308008000] [swscaler @ 0x14a210000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x308008000] [swscaler @ 0x14a220000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x308008000] [swscaler @ 0x14a230000] No accelerated colorspace conversion found from yuv420p to rgb24.
# Output #0, image2, to 'pipe:':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Stream #0:0: Video: png, rgb24(pc, gbr/bt709/bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 23.98 fps, 23.98 tbn (default)
#     Metadata:
#       encoder         : Lavc62.11.100 png
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
# [image2 @ 0x140727bf0] The specified filename 'pipe:' does not contain an image sequence pattern or a pattern is invalid.
# [image2 @ 0x140727bf0] Use a pattern such as %03d for an image sequence or use the -update option (with -frames:v 1 if needed) to write a single image.
# [out#0/image2 @ 0x140727800] video:2382KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame=    1 fps=0.0 q=-0.0 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=0.164x elapsed=0:00:00.25

# %% [markdown]
# # make a folder to store the keyframes

# %%
import os

# %%
folder_name = "keyframes"
os.makedirs(folder_name, exist_ok=True)

# %% [markdown]
# delete all the files in the folder

# %%
for file in Path(folder_name).iterdir():
    if file.is_file():
        file.unlink()

# %%
no = 0
for keyframe in keyframes:
    no += 1
    time = keyframe.get("pts_time")
    get_keyframe_image(time, no)
# Out:
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kuntalsuman/Downloads/demo.mov':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Duration: 00:01:00.06, start: 0.000000, bitrate: 2492 kb/s
#   Stream #0:0[0x1]: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x1487d0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1487d0000] [swscaler @ 0x1487e0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1487d0000] [swscaler @ 0x1487f0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1487d0000] [swscaler @ 0x148800000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1487d0000] [swscaler @ 0x148810000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1487d0000] [swscaler @ 0x148820000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1487d0000] [swscaler @ 0x148830000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1487d0000] [swscaler @ 0x148840000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1487d0000] [swscaler @ 0x148850000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1487d0000] [swscaler @ 0x148860000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1487d0000] [swscaler @ 0x148870000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1487d0000] [swscaler @ 0x148880000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1487d0000] [swscaler @ 0x152178000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1487d0000] [swscaler @ 0x152188000] No accelerated colorspace conversion found from yuv420p to rgb24.
# Output #0, image2, to 'pipe:':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Stream #0:0: Video: png, rgb24(pc, gbr/bt709/bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 23.98 fps, 23.98 tbn (default)
#     Metadata:
#       encoder         : Lavc62.11.100 png
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
# [image2 @ 0x11ae041e0] The specified filename 'pipe:' does not contain an image sequence pattern or a pattern is invalid.
# [image2 @ 0x11ae041e0] Use a pattern such as %03d for an image sequence or use the -update option (with -frames:v 1 if needed) to write a single image.
# [out#0/image2 @ 0x11ae04110] video:2382KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame=    1 fps=0.0 q=-0.0 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=0.164x elapsed=0:00:00.25
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kuntalsuman/Downloads/demo.mov':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Duration: 00:01:00.06, start: 0.000000, bitrate: 2492 kb/s
#   Stream #0:0[0x1]: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [h264 @ 0x14d018d60] mmco: unref short failure
# [swscaler @ 0x151488000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x151488000] [swscaler @ 0x151498000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x151488000] [swscaler @ 0x1514a8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x151488000] [swscaler @ 0x1514b8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x151488000] [swscaler @ 0x1514c8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x151488000] [swscaler @ 0x1514d8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x151488000] [swscaler @ 0x1514e8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x151488000] [swscaler @ 0x1514f8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x151488000] [swscaler @ 0x151508000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x151488000] [swscaler @ 0x151518000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x151488000] [swscaler @ 0x151528000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x151488000] [swscaler @ 0x151538000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x151488000] [swscaler @ 0x151548000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x151488000] [swscaler @ 0x151558000] No accelerated colorspace conversion found from yuv420p to rgb24.
# Output #0, image2, to 'pipe:':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Stream #0:0: Video: png, rgb24(pc, gbr/bt709/bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 23.98 fps, 23.98 tbn (default)
#     Metadata:
#       encoder         : Lavc62.11.100 png
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
# [image2 @ 0x14d005110] The specified filename 'pipe:' does not contain an image sequence pattern or a pattern is invalid.
# [image2 @ 0x14d005110] Use a pattern such as %03d for an image sequence or use the -update option (with -frames:v 1 if needed) to write a single image.
# [out#0/image2 @ 0x14d005050] video:1994KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame=    1 fps=0.0 q=-0.0 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=0.17x elapsed=0:00:00.24
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kuntalsuman/Downloads/demo.mov':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Duration: 00:01:00.06, start: 0.000000, bitrate: 2492 kb/s
#   Stream #0:0[0x1]: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x139690000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x139690000] [swscaler @ 0x1396a0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x139690000] [swscaler @ 0x1396b0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x139690000] [swscaler @ 0x1396c0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x139690000] [swscaler @ 0x1396d0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x139690000] [swscaler @ 0x1396e0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x139690000] [swscaler @ 0x1396f0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x139690000] [swscaler @ 0x139700000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x139690000] [swscaler @ 0x139710000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x139690000] [swscaler @ 0x139720000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x139690000] [swscaler @ 0x139730000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x139690000] [swscaler @ 0x139740000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x139690000] [swscaler @ 0x139750000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x139690000] [swscaler @ 0x139760000] No accelerated colorspace conversion found from yuv420p to rgb24.
# Output #0, image2, to 'pipe:':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Stream #0:0: Video: png, rgb24(pc, gbr/bt709/bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 23.98 fps, 23.98 tbn (default)
#     Metadata:
#       encoder         : Lavc62.11.100 png
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
# [image2 @ 0x157005110] The specified filename 'pipe:' does not contain an image sequence pattern or a pattern is invalid.
# [image2 @ 0x157005110] Use a pattern such as %03d for an image sequence or use the -update option (with -frames:v 1 if needed) to write a single image.
# [out#0/image2 @ 0x157005050] video:1577KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame=    1 fps=0.0 q=-0.0 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=0.215x elapsed=0:00:00.19
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kuntalsuman/Downloads/demo.mov':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Duration: 00:01:00.06, start: 0.000000, bitrate: 2492 kb/s
#   Stream #0:0[0x1]: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x128d20000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128d20000] [swscaler @ 0x128d30000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128d20000] [swscaler @ 0x128d40000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128d20000] [swscaler @ 0x128d50000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128d20000] [swscaler @ 0x128d60000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128d20000] [swscaler @ 0x128d70000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128d20000] [swscaler @ 0x128d80000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128d20000] [swscaler @ 0x128d90000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128d20000] [swscaler @ 0x128da0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128d20000] [swscaler @ 0x128db0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128d20000] [swscaler @ 0x128dc0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128d20000] [swscaler @ 0x128dd0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128d20000] [swscaler @ 0x128de0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x128d20000] [swscaler @ 0x1193c8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# Output #0, image2, to 'pipe:':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Stream #0:0: Video: png, rgb24(pc, gbr/bt709/bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 23.98 fps, 23.98 tbn (default)
#     Metadata:
#       encoder         : Lavc62.11.100 png
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
# [image2 @ 0x152f05110] The specified filename 'pipe:' does not contain an image sequence pattern or a pattern is invalid.
# [image2 @ 0x152f05110] Use a pattern such as %03d for an image sequence or use the -update option (with -frames:v 1 if needed) to write a single image.
# [out#0/image2 @ 0x152f05050] video:852KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame=    1 fps=0.0 q=-0.0 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=0.496x elapsed=0:00:00.08
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kuntalsuman/Downloads/demo.mov':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Duration: 00:01:00.06, start: 0.000000, bitrate: 2492 kb/s
#   Stream #0:0[0x1]: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x1581f8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1581f8000] [swscaler @ 0x158208000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1581f8000] [swscaler @ 0x158218000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1581f8000] [swscaler @ 0x158228000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1581f8000] [swscaler @ 0x158238000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1581f8000] [swscaler @ 0x158248000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1581f8000] [swscaler @ 0x158258000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1581f8000] [swscaler @ 0x158268000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1581f8000] [swscaler @ 0x158278000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1581f8000] [swscaler @ 0x158288000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1581f8000] [swscaler @ 0x158298000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1581f8000] [swscaler @ 0x1582a8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1581f8000] [swscaler @ 0x1582b8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1581f8000] [swscaler @ 0x1582c8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# Output #0, image2, to 'pipe:':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Stream #0:0: Video: png, rgb24(pc, gbr/bt709/bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 23.98 fps, 23.98 tbn (default)
#     Metadata:
#       encoder         : Lavc62.11.100 png
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
# [image2 @ 0x113604440] The specified filename 'pipe:' does not contain an image sequence pattern or a pattern is invalid.
# [image2 @ 0x113604440] Use a pattern such as %03d for an image sequence or use the -update option (with -frames:v 1 if needed) to write a single image.
# [out#0/image2 @ 0x113604100] video:1885KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame=    1 fps=0.0 q=-0.0 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=0.171x elapsed=0:00:00.24
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kuntalsuman/Downloads/demo.mov':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Duration: 00:01:00.06, start: 0.000000, bitrate: 2492 kb/s
#   Stream #0:0[0x1]: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x151390000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x151390000] [swscaler @ 0x1513a0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x151390000] [swscaler @ 0x1513b0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x151390000] [swscaler @ 0x1513c0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x151390000] [swscaler @ 0x1513d0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x151390000] [swscaler @ 0x1513e0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x151390000] [swscaler @ 0x1513f0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x151390000] [swscaler @ 0x151400000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x151390000] [swscaler @ 0x151410000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x151390000] [swscaler @ 0x151420000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x151390000] [swscaler @ 0x151430000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x151390000] [swscaler @ 0x151440000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x151390000] [swscaler @ 0x151450000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x151390000] [swscaler @ 0x151460000] No accelerated colorspace conversion found from yuv420p to rgb24.
# Output #0, image2, to 'pipe:':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Stream #0:0: Video: png, rgb24(pc, gbr/bt709/bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 23.98 fps, 23.98 tbn (default)
#     Metadata:
#       encoder         : Lavc62.11.100 png
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
# [image2 @ 0x147e33a10] The specified filename 'pipe:' does not contain an image sequence pattern or a pattern is invalid.
# [image2 @ 0x147e33a10] Use a pattern such as %03d for an image sequence or use the -update option (with -frames:v 1 if needed) to write a single image.
# [out#0/image2 @ 0x147e418f0] video:2544KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame=    1 fps=0.0 q=-0.0 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=0.167x elapsed=0:00:00.24
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kuntalsuman/Downloads/demo.mov':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Duration: 00:01:00.06, start: 0.000000, bitrate: 2492 kb/s
#   Stream #0:0[0x1]: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x178008000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x178008000] [swscaler @ 0x111610000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x178008000] [swscaler @ 0x111620000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x178008000] [swscaler @ 0x111630000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x178008000] [swscaler @ 0x111640000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x178008000] [swscaler @ 0x111650000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x178008000] [swscaler @ 0x111660000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x178008000] [swscaler @ 0x111670000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x178008000] [swscaler @ 0x111680000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x178008000] [swscaler @ 0x111690000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x178008000] [swscaler @ 0x1116a0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x178008000] [swscaler @ 0x1116b0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x178008000] [swscaler @ 0x1116c0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x178008000] [swscaler @ 0x1116d0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# Output #0, image2, to 'pipe:':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Stream #0:0: Video: png, rgb24(pc, gbr/bt709/bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 23.98 fps, 23.98 tbn (default)
#     Metadata:
#       encoder         : Lavc62.11.100 png
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
# [image2 @ 0x12d633090] The specified filename 'pipe:' does not contain an image sequence pattern or a pattern is invalid.
# [image2 @ 0x12d633090] Use a pattern such as %03d for an image sequence or use the -update option (with -frames:v 1 if needed) to write a single image.
# [out#0/image2 @ 0x12d632d40] video:1354KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame=    1 fps=0.0 q=-0.0 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=0.232x elapsed=0:00:00.17
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kuntalsuman/Downloads/demo.mov':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Duration: 00:01:00.06, start: 0.000000, bitrate: 2492 kb/s
#   Stream #0:0[0x1]: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x1083d8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1083d8000] [swscaler @ 0x13a340000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1083d8000] [swscaler @ 0x13a350000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1083d8000] [swscaler @ 0x13a360000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1083d8000] [swscaler @ 0x13a370000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1083d8000] [swscaler @ 0x13a380000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1083d8000] [swscaler @ 0x13a390000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1083d8000] [swscaler @ 0x1083e8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1083d8000] [swscaler @ 0x1083f8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1083d8000] [swscaler @ 0x108408000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1083d8000] [swscaler @ 0x108418000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1083d8000] [swscaler @ 0x108428000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1083d8000] [swscaler @ 0x108438000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1083d8000] [swscaler @ 0x108448000] No accelerated colorspace conversion found from yuv420p to rgb24.
# Output #0, image2, to 'pipe:':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Stream #0:0: Video: png, rgb24(pc, gbr/bt709/bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 23.98 fps, 23.98 tbn (default)
#     Metadata:
#       encoder         : Lavc62.11.100 png
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
# [image2 @ 0x144e33090] The specified filename 'pipe:' does not contain an image sequence pattern or a pattern is invalid.
# [image2 @ 0x144e33090] Use a pattern such as %03d for an image sequence or use the -update option (with -frames:v 1 if needed) to write a single image.
# [out#0/image2 @ 0x144e32d40] video:2143KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame=    1 fps=0.0 q=-0.0 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=0.183x elapsed=0:00:00.22
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kuntalsuman/Downloads/demo.mov':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Duration: 00:01:00.06, start: 0.000000, bitrate: 2492 kb/s
#   Stream #0:0[0x1]: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x1402e0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1402e0000] [swscaler @ 0x1402f0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1402e0000] [swscaler @ 0x140300000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1402e0000] [swscaler @ 0x140310000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1402e0000] [swscaler @ 0x140320000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1402e0000] [swscaler @ 0x140330000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1402e0000] [swscaler @ 0x140340000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1402e0000] [swscaler @ 0x140350000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1402e0000] [swscaler @ 0x140360000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1402e0000] [swscaler @ 0x140370000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1402e0000] [swscaler @ 0x140380000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1402e0000] [swscaler @ 0x140390000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1402e0000] [swscaler @ 0x1403a0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x1402e0000] [swscaler @ 0x1403b0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# Output #0, image2, to 'pipe:':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Stream #0:0: Video: png, rgb24(pc, gbr/bt709/bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 23.98 fps, 23.98 tbn (default)
#     Metadata:
#       encoder         : Lavc62.11.100 png
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
# [image2 @ 0x15a0183f0] The specified filename 'pipe:' does not contain an image sequence pattern or a pattern is invalid.
# [image2 @ 0x15a0183f0] Use a pattern such as %03d for an image sequence or use the -update option (with -frames:v 1 if needed) to write a single image.
# [out#0/image2 @ 0x15a018330] video:1042KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame=    1 fps=0.0 q=-0.0 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=0.53x elapsed=0:00:00.07
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kuntalsuman/Downloads/demo.mov':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Duration: 00:01:00.06, start: 0.000000, bitrate: 2492 kb/s
#   Stream #0:0[0x1]: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x158998000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x158998000] [swscaler @ 0x1589a8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x158998000] [swscaler @ 0x1589b8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x158998000] [swscaler @ 0x1589c8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x158998000] [swscaler @ 0x1589d8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x158998000] [swscaler @ 0x1589e8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x158998000] [swscaler @ 0x1589f8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x158998000] [swscaler @ 0x158a08000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x158998000] [swscaler @ 0x158a18000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x158998000] [swscaler @ 0x158a28000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x158998000] [swscaler @ 0x158a38000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x158998000] [swscaler @ 0x158a48000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x158998000] [swscaler @ 0x158a58000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x158998000] [swscaler @ 0x158a68000] No accelerated colorspace conversion found from yuv420p to rgb24.
# Output #0, image2, to 'pipe:':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Stream #0:0: Video: png, rgb24(pc, gbr/bt709/bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 23.98 fps, 23.98 tbn (default)
#     Metadata:
#       encoder         : Lavc62.11.100 png
#       handler_name    : ISO Media file produced by Google Inc.
# ...
# [swscaler @ 0x140990000] [swscaler @ 0x140a30000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x140990000] [swscaler @ 0x140a40000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x140990000] [swscaler @ 0x140a50000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x140990000] [swscaler @ 0x140a60000] No accelerated colorspace conversion found from yuv420p to rgb24.
# Output #0, image2, to 'pipe:':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Stream #0:0: Video: png, rgb24(pc, gbr/bt709/bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 23.98 fps, 23.98 tbn (default)
#     Metadata:
#       encoder         : Lavc62.11.100 png
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
# [image2 @ 0x132e3b690] The specified filename 'pipe:' does not contain an image sequence pattern or a pattern is invalid.
# [image2 @ 0x132e3b690] Use a pattern such as %03d for an image sequence or use the -update option (with -frames:v 1 if needed) to write a single image.
# [out#0/image2 @ 0x132e32d50] video:768KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame=    1 fps=0.0 q=-0.0 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=0.587x elapsed=0:00:00.07
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kuntalsuman/Downloads/demo.mov':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Duration: 00:01:00.06, start: 0.000000, bitrate: 2492 kb/s
#   Stream #0:0[0x1]: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x170018000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x170018000] [swscaler @ 0x170028000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x170018000] [swscaler @ 0x170038000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x170018000] [swscaler @ 0x170048000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x170018000] [swscaler @ 0x170058000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x170018000] [swscaler @ 0x170068000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x170018000] [swscaler @ 0x170078000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x170018000] [swscaler @ 0x170088000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x170018000] [swscaler @ 0x170098000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x170018000] [swscaler @ 0x1700a8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x170018000] [swscaler @ 0x1700b8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x170018000] [swscaler @ 0x1700c8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x170018000] [swscaler @ 0x1700d8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x170018000] [swscaler @ 0x1700e8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# Output #0, image2, to 'pipe:':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Stream #0:0: Video: png, rgb24(pc, gbr/bt709/bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 23.98 fps, 23.98 tbn (default)
#     Metadata:
#       encoder         : Lavc62.11.100 png
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
# [image2 @ 0x148706260] The specified filename 'pipe:' does not contain an image sequence pattern or a pattern is invalid.
# [image2 @ 0x148706260] Use a pattern such as %03d for an image sequence or use the -update option (with -frames:v 1 if needed) to write a single image.
# [out#0/image2 @ 0x148705e20] video:1031KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame=    1 fps=0.0 q=-0.0 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=0.547x elapsed=0:00:00.07
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kuntalsuman/Downloads/demo.mov':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Duration: 00:01:00.06, start: 0.000000, bitrate: 2492 kb/s
#   Stream #0:0[0x1]: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x131a78000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x131a78000] [swscaler @ 0x131a88000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x131a78000] [swscaler @ 0x131a98000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x131a78000] [swscaler @ 0x131aa8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x131a78000] [swscaler @ 0x131ab8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x131a78000] [swscaler @ 0x131ac8000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x131a78000] [swscaler @ 0x300008000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x131a78000] [swscaler @ 0x150c18000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x131a78000] [swscaler @ 0x150c28000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x131a78000] [swscaler @ 0x150c38000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x131a78000] [swscaler @ 0x150c48000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x131a78000] [swscaler @ 0x150c58000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x131a78000] [swscaler @ 0x150c68000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x131a78000] [swscaler @ 0x150c78000] No accelerated colorspace conversion found from yuv420p to rgb24.
# Output #0, image2, to 'pipe:':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Stream #0:0: Video: png, rgb24(pc, gbr/bt709/bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 23.98 fps, 23.98 tbn (default)
#     Metadata:
#       encoder         : Lavc62.11.100 png
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
# [image2 @ 0x1287059e0] The specified filename 'pipe:' does not contain an image sequence pattern or a pattern is invalid.
# [image2 @ 0x1287059e0] Use a pattern such as %03d for an image sequence or use the -update option (with -frames:v 1 if needed) to write a single image.
# [out#0/image2 @ 0x128705920] video:616KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame=    1 fps=0.0 q=-0.0 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=0.634x elapsed=0:00:00.06
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kuntalsuman/Downloads/demo.mov':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Duration: 00:01:00.06, start: 0.000000, bitrate: 2492 kb/s
#   Stream #0:0[0x1]: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x158070000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x158070000] [swscaler @ 0x119740000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x158070000] [swscaler @ 0x119750000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x158070000] [swscaler @ 0x119760000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x158070000] [swscaler @ 0x308008000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x158070000] [swscaler @ 0x119770000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x158070000] [swscaler @ 0x119780000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x158070000] [swscaler @ 0x119790000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x158070000] [swscaler @ 0x1197a0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x158070000] [swscaler @ 0x1197b0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x158070000] [swscaler @ 0x1197c0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x158070000] [swscaler @ 0x1197d0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x158070000] [swscaler @ 0x1197e0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# [swscaler @ 0x158070000] [swscaler @ 0x1197f0000] No accelerated colorspace conversion found from yuv420p to rgb24.
# Output #0, image2, to 'pipe:':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Stream #0:0: Video: png, rgb24(pc, gbr/bt709/bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 23.98 fps, 23.98 tbn (default)
#     Metadata:
#       encoder         : Lavc62.11.100 png
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
# [image2 @ 0x117e04190] The specified filename 'pipe:' does not contain an image sequence pattern or a pattern is invalid.
# [image2 @ 0x117e04190] Use a pattern such as %03d for an image sequence or use the -update option (with -frames:v 1 if needed) to write a single image.
# [out#0/image2 @ 0x117e040d0] video:571KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame=    1 fps=0.0 q=-0.0 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=0.598x elapsed=0:00:00.06

# %%
video_folder = "video_between_keyframes"

# %%
os.makedirs(video_folder, exist_ok=True)

# %%
for file in Path(video_folder).iterdir():
    if file.is_file():
        file.unlink()

# %%
def slice_videos(t0, t1, part):
    ffmpeg_command_to_slice_video = f"ffmpeg -ss 00:{t0} -to 00:{t1} -i {video_path} -c copy -avoid_negative_ts make_zero {video_folder}/slice{part}.mp4"
    subprocess.call(ffmpeg_command_to_slice_video, shell=True)

# %%
for i in range(0, 23):
    t0 = keyframes[i].get("pts_time")
    t1 = keyframes[i+1].get("pts_time")
    part = i+1
    slice_videos(t0, t1, part)
# Out:
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kuntalsuman/Downloads/demo.mov':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Duration: 00:01:00.06, start: 0.000000, bitrate: 2492 kb/s
#   Stream #0:0[0x1]: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Output #0, mp4, to 'video_between_keyframes/slice1.mp4':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Stream #0:0: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Press [q] to stop, [?] for help
# [out#0/mp4 @ 0x13a705050] video:755KiB audio:23KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.322047%
# frame=   34 fps=0.0 q=-1.0 Lsize=     780KiB time=00:00:01.37 bitrate=4640.7kbits/s speed=2.32e+03x elapsed=0:00:00.00
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kuntalsuman/Downloads/demo.mov':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Duration: 00:01:00.06, start: 0.000000, bitrate: 2492 kb/s
#   Stream #0:0[0x1]: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Output #0, mp4, to 'video_between_keyframes/slice2.mp4':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Stream #0:0: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Press [q] to stop, [?] for help
# [out#0/mp4 @ 0x12af040f0] video:823KiB audio:29KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.336400%
# frame=   45 fps=0.0 q=-1.0 Lsize=     855KiB time=00:00:01.83 bitrate=3816.1kbits/s speed=2.91e+03x elapsed=0:00:00.00
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kuntalsuman/Downloads/demo.mov':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Duration: 00:01:00.06, start: 0.000000, bitrate: 2492 kb/s
#   Stream #0:0[0x1]: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Output #0, mp4, to 'video_between_keyframes/slice3.mp4':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Stream #0:0: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Press [q] to stop, [?] for help
# [out#0/mp4 @ 0x150705050] video:1390KiB audio:58KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.280965%
# frame=   88 fps=0.0 q=-1.0 Lsize=    1452KiB time=00:00:03.62 bitrate=3279.0kbits/s speed=3.85e+03x elapsed=0:00:00.00
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kuntalsuman/Downloads/demo.mov':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Duration: 00:01:00.06, start: 0.000000, bitrate: 2492 kb/s
#   Stream #0:0[0x1]: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Output #0, mp4, to 'video_between_keyframes/slice4.mp4':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Stream #0:0: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Press [q] to stop, [?] for help
# [out#0/mp4 @ 0x15a005050] video:568KiB audio:38KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.528647%
# frame=   58 fps=0.0 q=-1.0 Lsize=     610KiB time=00:00:02.37 bitrate=2100.8kbits/s speed=3.89e+03x elapsed=0:00:00.00
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kuntalsuman/Downloads/demo.mov':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Duration: 00:01:00.06, start: 0.000000, bitrate: 2492 kb/s
#   Stream #0:0[0x1]: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Output #0, mp4, to 'video_between_keyframes/slice5.mp4':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Stream #0:0: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Press [q] to stop, [?] for help
# [out#0/mp4 @ 0x14bf27480] video:2404KiB audio:25KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.108686%
# frame=   38 fps=0.0 q=-1.0 Lsize=    2431KiB time=00:00:01.54 bitrate=12906.5kbits/s speed=1.93e+03x elapsed=0:00:00.00
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kuntalsuman/Downloads/demo.mov':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Duration: 00:01:00.06, start: 0.000000, bitrate: 2492 kb/s
#   Stream #0:0[0x1]: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Output #0, mp4, to 'video_between_keyframes/slice6.mp4':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Stream #0:0: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Press [q] to stop, [?] for help
# [out#0/mp4 @ 0x159e101c0] video:1097KiB audio:37KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.280806%
# frame=   56 fps=0.0 q=-1.0 Lsize=    1137KiB time=00:00:02.29 bitrate=4058.8kbits/s speed=2.63e+03x elapsed=0:00:00.00
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kuntalsuman/Downloads/demo.mov':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Duration: 00:01:00.06, start: 0.000000, bitrate: 2492 kb/s
#   Stream #0:0[0x1]: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Output #0, mp4, to 'video_between_keyframes/slice7.mp4':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Stream #0:0: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Press [q] to stop, [?] for help
# [out#0/mp4 @ 0x150005050] video:721KiB audio:29KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.378929%
# frame=   45 fps=0.0 q=-1.0 Lsize=     752KiB time=00:00:01.80 bitrate=3411.1kbits/s speed=2.48e+03x elapsed=0:00:00.00
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kuntalsuman/Downloads/demo.mov':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Duration: 00:01:00.06, start: 0.000000, bitrate: 2492 kb/s
#   Stream #0:0[0x1]: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Output #0, mp4, to 'video_between_keyframes/slice8.mp4':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Stream #0:0: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Press [q] to stop, [?] for help
# [out#0/mp4 @ 0x159705050] video:1855KiB audio:35KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.164648%
# frame=   53 fps=0.0 q=-1.0 Lsize=    1893KiB time=00:00:02.16 bitrate=7151.6kbits/s speed=1.95e+03x elapsed=0:00:00.00
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kuntalsuman/Downloads/demo.mov':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Duration: 00:01:00.06, start: 0.000000, bitrate: 2492 kb/s
#   Stream #0:0[0x1]: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Output #0, mp4, to 'video_between_keyframes/slice9.mp4':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Stream #0:0: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Press [q] to stop, [?] for help
# [out#0/mp4 @ 0x129e32d80] video:781KiB audio:51KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.451255%
# frame=   78 fps=0.0 q=-1.0 Lsize=     836KiB time=00:00:03.21 bitrate=2133.2kbits/s speed=2.97e+03x elapsed=0:00:00.00
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kuntalsuman/Downloads/demo.mov':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Duration: 00:01:00.06, start: 0.000000, bitrate: 2492 kb/s
#   Stream #0:0[0x1]: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Output #0, mp4, to 'video_between_keyframes/slice10.mp4':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Stream #0:0: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Press [q] to stop, [?] for help
# [out#0/mp4 @ 0x145005050] video:374KiB audio:27KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.670290%
# frame=   41 fps=0.0 q=-1.0 Lsize=     404KiB time=00:00:01.66 bitrate=1984.1kbits/s speed=3.65e+03x elapsed=0:00:00.00
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kuntalsuman/Downloads/demo.mov':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Duration: 00:01:00.06, start: 0.000000, bitrate: 2492 kb/s
#   Stream #0:0[0x1]: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Output #0, mp4, to 'video_between_keyframes/slice11.mp4':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Stream #0:0: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Press [q] to stop, [?] for help
# [out#0/mp4 @ 0x139e32d80] video:433KiB audio:28KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.594629%
# frame=   43 fps=0.0 q=-1.0 Lsize=     464KiB time=00:00:01.75 bitrate=2168.6kbits/s speed=3.28e+03x elapsed=0:00:00.00
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kuntalsuman/Downloads/demo.mov':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Duration: 00:01:00.06, start: 0.000000, bitrate: 2492 kb/s
#   Stream #0:0[0x1]: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Output #0, mp4, to 'video_between_keyframes/slice12.mp4':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Stream #0:0: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Press [q] to stop, [?] for help
# [out#0/mp4 @ 0x122705050] video:681KiB audio:43KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.469397%
# frame=   65 fps=0.0 q=-1.0 Lsize=     727KiB time=00:00:02.66 bitrate=2231.7kbits/s speed=3.84e+03x elapsed=0:00:00.00
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kuntalsuman/Downloads/demo.mov':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Duration: 00:01:00.06, start: 0.000000, bitrate: 2492 kb/s
#   Stream #0:0[0x1]: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Output #0, mp4, to 'video_between_keyframes/slice13.mp4':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Stream #0:0: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Press [q] to stop, [?] for help
# [out#0/mp4 @ 0x136f040a0] video:489KiB audio:28KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.525115%
# frame=   42 fps=0.0 q=-1.0 Lsize=     520KiB time=00:00:01.71 bitrate=2492.4kbits/s speed=2.31e+03x elapsed=0:00:00.00
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kuntalsuman/Downloads/demo.mov':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Duration: 00:01:00.06, start: 0.000000, bitrate: 2492 kb/s
#   Stream #0:0[0x1]: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Output #0, mp4, to 'video_between_keyframes/slice14.mp4':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Stream #0:0: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Press [q] to stop, [?] for help
# [out#0/mp4 @ 0x121105070] video:961KiB audio:79KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.490417%
# frame=  121 fps=0.0 q=-1.0 Lsize=    1045KiB time=00:00:05.00 bitrate=1710.7kbits/s speed=2.25e+03x elapsed=0:00:00.00
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kuntalsuman/Downloads/demo.mov':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Duration: 00:01:00.06, start: 0.000000, bitrate: 2492 kb/s
#   Stream #0:0[0x1]: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Output #0, mp4, to 'video_between_keyframes/slice15.mp4':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Stream #0:0: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
# ...
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kuntalsuman/Downloads/demo.mov':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Duration: 00:01:00.06, start: 0.000000, bitrate: 2492 kb/s
#   Stream #0:0[0x1]: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Output #0, mp4, to 'video_between_keyframes/slice19.mp4':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Stream #0:0: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Press [q] to stop, [?] for help
# [out#0/mp4 @ 0x132705050] video:825KiB audio:74KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.534885%
# frame=  113 fps=0.0 q=-1.0 Lsize=     904KiB time=00:00:04.67 bitrate=1584.7kbits/s speed=4.69e+03x elapsed=0:00:00.00
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kuntalsuman/Downloads/demo.mov':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Duration: 00:01:00.06, start: 0.000000, bitrate: 2492 kb/s
#   Stream #0:0[0x1]: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Output #0, mp4, to 'video_between_keyframes/slice20.mp4':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Stream #0:0: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Press [q] to stop, [?] for help
# [out#0/mp4 @ 0x13c105d20] video:399KiB audio:20KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.565075%
# frame=   30 fps=0.0 q=-1.0 Lsize=     421KiB time=00:00:01.20 bitrate=2852.1kbits/s speed=1.78e+03x elapsed=0:00:00.00
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kuntalsuman/Downloads/demo.mov':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Duration: 00:01:00.06, start: 0.000000, bitrate: 2492 kb/s
#   Stream #0:0[0x1]: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Output #0, mp4, to 'video_between_keyframes/slice21.mp4':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Stream #0:0: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Press [q] to stop, [?] for help
# [out#0/mp4 @ 0x120f05050] video:320KiB audio:21KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.713735%
# frame=   32 fps=0.0 q=-1.0 Lsize=     343KiB time=00:00:01.29 bitrate=2174.9kbits/s speed=2.26e+03x elapsed=0:00:00.00
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kuntalsuman/Downloads/demo.mov':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Duration: 00:01:00.06, start: 0.000000, bitrate: 2492 kb/s
#   Stream #0:0[0x1]: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Output #0, mp4, to 'video_between_keyframes/slice22.mp4':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Stream #0:0: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Press [q] to stop, [?] for help
# [out#0/mp4 @ 0x12d705050] video:765KiB audio:45KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.428848%
# frame=   68 fps=0.0 q=-1.0 Lsize=     813KiB time=00:00:02.79 bitrate=2383.3kbits/s speed=1.51e+03x elapsed=0:00:00.00
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/kuntalsuman/Downloads/demo.mov':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Duration: 00:01:00.06, start: 0.000000, bitrate: 2492 kb/s
#   Stream #0:0[0x1]: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Output #0, mp4, to 'video_between_keyframes/slice23.mp4':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 512
#     compatible_brands: qt
#     encoder         : Lavf62.3.100
#   Stream #0:0: Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 2358 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : FFMP
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Press [q] to stop, [?] for help
# [out#0/mp4 @ 0x14f8040a0] video:253KiB audio:16KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.821407%
# frame=   24 fps=0.0 q=-1.0 Lsize=     271KiB time=00:00:00.95 bitrate=2312.3kbits/s speed=2.18e+03x elapsed=0:00:00.00
